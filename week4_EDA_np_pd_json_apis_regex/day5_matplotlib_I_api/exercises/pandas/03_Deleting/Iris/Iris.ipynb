# %% [markdown]
# # 03 - Deleting & handling missing values - Iris

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
iris = pd.read_csv("iris.data")
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 4. Call the columns for the dataset as follows:
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

# %%
iris = pd.read_csv("iris.data", names=["sepal_length (in cm)", "sepal_width (in cm)","petal_length (in cm)","petal_width (in cm)", "class"])
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# ..                   ...             ...
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
iris.isnull()
pd.isna(iris)
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   False                False                 False
# 1                   False                False                 False
# 2                   False                False                 False
# 3                   False                False                 False
# 4                   False                False                 False
# ..                    ...                  ...                   ...
# 145                 False                False                 False
# 146                 False                False                 False
# 147                 False                False                 False
# 148                 False                False                 False
# 149                 False                False                 False
#
#      petal_width (in cm)  class
# 0                  False  False
# 1                  False  False
# 2                  False  False
# 3                  False  False
# 4                  False  False
# ..                   ...    ...
# 145                False  False
# 146                False  False
# 147                False  False
# 148                False  False
# 149                False  False
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.loc[10:30, "petal_legnth (in cm)"] = np.NaN
iris[10:30]
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# 13                   4.3                  3.0                   1.1
# 14                   5.8                  4.0                   1.2
# 15                   5.7                  4.4                   1.5
# 16                   5.4                  3.9                   1.3
# 17                   5.1                  3.5                   1.4
# 18                   5.7                  3.8                   1.7
# 19                   5.1                  3.8                   1.5
# 20                   5.4                  3.4                   1.7
# 21                   5.1                  3.7                   1.5
# 22                   4.6                  3.6                   1.0
# 23                   5.1                  3.3                   1.7
# 24                   4.8                  3.4                   1.9
# 25                   5.0                  3.0                   1.6
# 26                   5.0                  3.4                   1.6
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
#
#     petal_width (in cm)        class  petal_legnth (in cm)
# 10                  0.2  Iris-setosa                   NaN
# 11                  0.2  Iris-setosa                   NaN
# 12                  0.1  Iris-setosa                   NaN
# 13                  0.1  Iris-setosa                   NaN
# 14                  0.2  Iris-setosa                   NaN
# 15                  0.4  Iris-setosa                   NaN
# 16                  0.4  Iris-setosa                   NaN
# 17                  0.3  Iris-setosa                   NaN
# 18                  0.3  Iris-setosa                   NaN
# 19                  0.3  Iris-setosa                   NaN
# 20                  0.2  Iris-setosa                   NaN
# 21                  0.4  Iris-setosa                   NaN
# 22                  0.2  Iris-setosa                   NaN
# 23                  0.5  Iris-setosa                   NaN
# 24                  0.2  Iris-setosa                   NaN
# 25                  0.2  Iris-setosa                   NaN
# 26                  0.4  Iris-setosa                   NaN
# 27                  0.2  Iris-setosa                   NaN
# 28                  0.2  Iris-setosa                   NaN
# 29                  0.2  Iris-setosa                   NaN

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
values = {"petal_legnth (in cm)": 1.0}
iris = iris.fillna(value=values)
iris[10:30]
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# 13                   4.3                  3.0                   1.1
# 14                   5.8                  4.0                   1.2
# 15                   5.7                  4.4                   1.5
# 16                   5.4                  3.9                   1.3
# 17                   5.1                  3.5                   1.4
# 18                   5.7                  3.8                   1.7
# 19                   5.1                  3.8                   1.5
# 20                   5.4                  3.4                   1.7
# 21                   5.1                  3.7                   1.5
# 22                   4.6                  3.6                   1.0
# 23                   5.1                  3.3                   1.7
# 24                   4.8                  3.4                   1.9
# 25                   5.0                  3.0                   1.6
# 26                   5.0                  3.4                   1.6
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
#
#     petal_width (in cm)        class  petal_legnth (in cm)
# 10                  0.2  Iris-setosa                   1.0
# 11                  0.2  Iris-setosa                   1.0
# 12                  0.1  Iris-setosa                   1.0
# 13                  0.1  Iris-setosa                   1.0
# 14                  0.2  Iris-setosa                   1.0
# 15                  0.4  Iris-setosa                   1.0
# 16                  0.4  Iris-setosa                   1.0
# 17                  0.3  Iris-setosa                   1.0
# 18                  0.3  Iris-setosa                   1.0
# 19                  0.3  Iris-setosa                   1.0
# 20                  0.2  Iris-setosa                   1.0
# 21                  0.4  Iris-setosa                   1.0
# 22                  0.2  Iris-setosa                   1.0
# 23                  0.5  Iris-setosa                   1.0
# 24                  0.2  Iris-setosa                   1.0
# 25                  0.2  Iris-setosa                   1.0
# 26                  0.4  Iris-setosa                   1.0
# 27                  0.2  Iris-setosa                   1.0
# 28                  0.2  Iris-setosa                   1.0
# 29                  0.2  Iris-setosa                   1.0

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
iris.drop(columns="class")
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)  petal_legnth (in cm)
# 0                    0.2                   1.0
# 1                    0.2                   1.0
# 2                    0.2                   1.0
# 3                    0.2                   1.0
# 4                    0.2                   1.0
# ..                   ...                   ...
# 145                  2.3                   1.0
# 146                  1.9                   1.0
# 147                  2.0                   1.0
# 148                  2.3                   1.0
# 149                  1.8                   1.0
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.iloc[:3] = np.nan
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     NaN                  NaN                   NaN
# 1                     NaN                  NaN                   NaN
# 2                     NaN                  NaN                   NaN
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class  petal_legnth (in cm)
# 0                    NaN             NaN                   NaN
# 1                    NaN             NaN                   NaN
# 2                    NaN             NaN                   NaN
# 3                    0.2     Iris-setosa                   1.0
# 4                    0.2     Iris-setosa                   1.0
# ..                   ...             ...                   ...
# 145                  2.3  Iris-virginica                   1.0
# 146                  1.9  Iris-virginica                   1.0
# 147                  2.0  Iris-virginica                   1.0
# 148                  2.3  Iris-virginica                   1.0
# 149                  1.8  Iris-virginica                   1.0
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris = iris.dropna()
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class  petal_legnth (in cm)
# 3                    0.2     Iris-setosa                   1.0
# 4                    0.2     Iris-setosa                   1.0
# 5                    0.4     Iris-setosa                   1.0
# 6                    0.3     Iris-setosa                   1.0
# 7                    0.2     Iris-setosa                   1.0
# ..                   ...             ...                   ...
# 145                  2.3  Iris-virginica                   1.0
# 146                  1.9  Iris-virginica                   1.0
# 147                  2.0  Iris-virginica                   1.0
# 148                  2.3  Iris-virginica                   1.0
# 149                  1.8  Iris-virginica                   1.0
#
# [147 rows x 6 columns]

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(drop=True)
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     4.6                  3.1                   1.5
# 1                     5.0                  3.6                   1.4
# 2                     5.4                  3.9                   1.7
# 3                     4.6                  3.4                   1.4
# 4                     5.0                  3.4                   1.5
# ..                    ...                  ...                   ...
# 142                   6.7                  3.0                   5.2
# 143                   6.3                  2.5                   5.0
# 144                   6.5                  3.0                   5.2
# 145                   6.2                  3.4                   5.4
# 146                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class  petal_legnth (in cm)
# 0                    0.2     Iris-setosa                   1.0
# 1                    0.2     Iris-setosa                   1.0
# 2                    0.4     Iris-setosa                   1.0
# 3                    0.3     Iris-setosa                   1.0
# 4                    0.2     Iris-setosa                   1.0
# ..                   ...             ...                   ...
# 142                  2.3  Iris-virginica                   1.0
# 143                  1.9  Iris-virginica                   1.0
# 144                  2.0  Iris-virginica                   1.0
# 145                  2.3  Iris-virginica                   1.0
# 146                  1.8  Iris-virginica                   1.0
#
# [147 rows x 6 columns]
