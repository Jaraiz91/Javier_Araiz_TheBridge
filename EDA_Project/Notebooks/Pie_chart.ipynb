# %%
import matplotlib.pyplot as plt

# %%
steps = ['Data Wrangling and cleaning', 'Data visualization', 'Streamlit', 'Flask']
percentages = [50, 30, 10, 10]
plt.figure(figsize=(20,10))
plt.pie(percentages, labels= steps, wedgeprops= {'linewidth': 3, 'edgecolor': 'white'});
