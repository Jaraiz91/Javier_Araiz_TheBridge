# %%
import sqlite3 as sql
import pandas as pd
import matplotlib.pyplot as plt
import pyodbc

# %%
Brent = pd.read_csv('../Data/Def_Data/Brent_yearly.csv')
Brent.rename(columns={'Unnamed: 0': 'YEAR'})
# Out:
#     YEAR  Brent price
# 0   1992    19.319728
# 1   1993    17.013413
# 2   1994    15.856389
# 3   1995    17.015850
# 4   1996    20.639803
# 5   1997    19.108508
# 6   1998    12.758103
# 7   1999    17.901566
# 8   2000    28.660672
# 9   2001    24.455720
# 10  2002    24.993255
# 11  2003    28.850814
# 12  2004    38.259693
# 13  2005    54.574553
# 14  2006    65.161765
# 15  2007    72.441160
# 16  2008    96.944348
# 17  2009    61.738770
# 18  2010    79.609444
# 19  2011   111.264274
# 20  2012   111.570683
# 21  2013   108.555000
# 22  2014    98.969606
# 23  2015    52.316549
# 24  2016    43.638000
# 25  2017    54.124805
# 26  2018    71.335000
# 27  2019    64.319845
# 28  2020    42.101016
# 29  2021    54.689375

# %%
seatrade = pd.read_csv('../Data/Def_Data/df_sea_trade.csv')
seatrade = seatrade.drop(columns=['Unnamed: 0'])
seatrade
# Out:
#           YEAR  "Crude oil loaded"  "Other tanker trade loaded"  \
# 0   1970-01-01            1207.000                     233.0000
# 1   1971-01-01            1210.000                     320.0000
# 2   1972-01-01            1321.000                     332.0000
# 3   1973-01-01            1514.000                     353.0000
# 4   1974-01-01            1497.000                     335.0000
# 5   1975-01-01            1364.000                     280.0000
# 6   1976-01-01            1555.000                     289.0000
# 7   1977-01-01            1599.000                     293.0000
# 8   1978-01-01            1604.000                     296.0000
# 9   1979-01-01            1725.000                     318.0000
# 10  1980-01-01            1527.000                     344.0000
# 11  1981-01-01            1364.000                     327.0000
# 12  1982-01-01            1163.000                     350.0000
# 13  1983-01-01            1069.000                     392.0000
# ...

# %%
GDP = pd.read_csv('../Data/Def_Data/GDP_world.csv')
GDP = GDP.drop(columns=['Unnamed: 0'])
GDP
# Out:
#     Year                    Series Label  Economy Economy Label  \
# 0   1970  "Total gross domestic product"        0       "World"
# 1   1971  "Total gross domestic product"        0       "World"
# 2   1972  "Total gross domestic product"        0       "World"
# 3   1973  "Total gross domestic product"        0       "World"
# 4   1974  "Total gross domestic product"        0       "World"
# 5   1975  "Total gross domestic product"        0       "World"
# 6   1976  "Total gross domestic product"        0       "World"
# 7   1977  "Total gross domestic product"        0       "World"
# 8   1978  "Total gross domestic product"        0       "World"
# 9   1979  "Total gross domestic product"        0       "World"
# 10  1980  "Total gross domestic product"        0       "World"
# 11  1981  "Total gross domestic product"        0       "World"
# 12  1982  "Total gross domestic product"        0       "World"
# 13  1983  "Total gross domestic product"        0       "World"
# ...

# %%
conn = sql.connect()

# %%
ip_dns = "54.87.229.244"
port = 25001
user = '16092222L'
password = 'jaraiz37'
bd_name = '16092222L_ds_april_2021_db'

# %%
conn = {'IP_DNS': ip_dns, 'PORT': port, 'USER': user, 'PASSWORD': password, 'BD_NAME': bd_name}

# %%
connection = sql.Connection(conn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b933a10e3625> in <module>
# ----> 1 connection = sql.Connection(conn)
#
# TypeError: expected str, bytes or os.PathLike object, not dict
