# %% [markdown]
# ### 1.
#
# Crear una función que reciba cuatro parámetros: una lista 'L', un número 'T', un número 'V' y un booleano 'S'. La función debe devolver otras dos listas: "lista_train_val" y "lista_test".
#
# - "lista_train_val" es una lista con dos elementos. Cada elemento es una lista: "list_train", que representa el conjunto de entrenamiento y "list_val", que representa el conjunto de validación.
# - "list_test" es el conjunto de test. Como mínimo ha de tener 1 elemento (si 'L' > 1).
# - "L" es cualquier lista de elementos. Al principio, entra con un tamaño completo (100%). Esta es la lista que se partirá y se generarán los conjuntos entrenamiento, de validación y de test.
# - "T" es un número entre 1 y 100 que va a representar el tamaño, en porcentaje, del conjunto de test "list_test".
# - "V" es un número entre 0 y 100 que va a representar el tamaño, en porcentaje, del conjunto de validación "list_val". Su valor por defecto es 0.
# - "S", que por defecto es False, determinará si los conjuntos "list_train", "list_test" y "list_val" están aleatoriamente ordenados. ¿Encuentras alguna posible incoherencia si se reordenan aleatoriamente?
#
# Prueba la función con una lista de 100 números aleatorios del 0 al 100.
#
# ### 2.
#
# Rehacer el ejercicio anterior en otra función para que no devuelva dos listas, sino los tres conjuntos:
#
# --> return list_train, list_val, list_test

# %%
import random
import numpy as np

# %%
def f1(L, T, V=0, S=False):
    import random
    test_num = round((T / 100) * len(L))
    val_num = round((V / 100) * len(L))
    list_test = []
    list_val = []
    list_train = []
    if S == False:
        list_test = L[:test_num]
        L = L[test_num:]
        if len(L) > 1:
            list_val = L[:val_num]
            L = L[val_num:]
            list_train = L
        else:
            list_train = L

    else:
        random.shuffle(L)
        list_test = L[:test_num]
        L = L[test_num :]
        if len(L) > 1:
            list_val = L[:val_num]
            L = L[val_num :]
            list_train = L
        else:
            list_train = L

    lista_train_val = [list_train, list_val]
    print('len list_train:',len(list_train))
    print('len list_val:',len(list_val))
    print('len list_test:',len(list_test))
    return lista_train_val, list_test

# %%
rand_list = [random.randint(1, 50) for x in range(100)]
rand_list
# Out:
# [42,
#  32,
#  35,
#  36,
#  9,
#  26,
#  27,
#  9,
#  50,
#  17,
#  17,
#  13,
#  23,
#  22,
#  15,
#  37,
#  7,
#  17,
#  23,
#  35,
#  9,
#  18,
#  39,
#  24,
#  43,
#  16,
#  9,
#  29,
#  41,
#  45,
#  19,
#  11,
#  12,
#  28,
#  39,
#  47,
#  3,
#  3,
#  32,
#  3,
#  12,
#  37,
#  24,
#  29,
#  22,
#  41,
#  20,
#  10,
#  43,
#  11,
#  25,
#  9,
#  38,
#  22,
#  20,
#  24,
#  48,
#  23,
#  17,
#  49,
#  27,
#  41,
#  47,
#  15,
#  50,
#  33,
#  43,
#  46,
#  11,
#  26,
#  49,
#  2,
#  37,
#  14,
#  17,
#  42,
#  34,
#  11,
#  27,
#  40,
#  2,
#  22,
#  9,
#  21,
#  50,
#  36,
#  23,
#  47,
#  46,
#  36,
#  10,
#  24,
#  7,
#  30,
#  21,
#  20,
#  45,
#  44,
#  1,
#  2]

# %%
f1(rand_list, T= 50, V= 10)
# Out:
# len list_train: 40
# len list_val: 10
# len list_test: 50
# ([[27,
#    41,
#    47,
#    15,
#    50,
#    33,
#    43,
#    46,
#    11,
#    26,
#    49,
#    2,
#    37,
#    14,
#    17,
#    42,
#    34,
#    11,
#    27,
#    40,
#    2,
#    22,
#    9,
#    21,
#    50,
#    36,
#    23,
#    47,
#    46,
#    36,
#    10,
#    24,
#    7,
#    30,
#    21,
#    20,
#    45,
#    44,
#    1,
#    2],
#   [25, 9, 38, 22, 20, 24, 48, 23, 17, 49]],
#  [42,
#   32,
#   35,
#   36,
#   9,
#   26,
#   27,
#   9,
#   50,
#   17,
#   17,
#   13,
#   23,
#   22,
#   15,
#   37,
#   7,
#   17,
#   23,
#   35,
#   9,
#   18,
#   39,
#   24,
#   43,
#   16,
#   9,
#   29,
#   41,
#   45,
#   19,
#   11,
#   12,
#   28,
#   39,
#   47,
#   3,
#   3,
#   32,
#   3,
#   12,
#   37,
#   24,
#   29,
#   22,
#   41,
#   20,
#   10,
#   43,
#   11])

# %%
# Si la lista se reordena aleatoreamente, solo está barajando los datos correspondientes a x, por lo que dejará de corresponder con los de y

# %%
f1(rand_list, T= 50, V= 10, S= True)
# Out:
# len list_train: 40
# len list_val: 10
# len list_test: 50
# ([[3,
#    16,
#    27,
#    19,
#    36,
#    46,
#    9,
#    36,
#    44,
#    41,
#    7,
#    9,
#    24,
#    22,
#    26,
#    9,
#    21,
#    50,
#    18,
#    17,
#    49,
#    39,
#    3,
#    15,
#    17,
#    2,
#    15,
#    24,
#    32,
#    23,
#    28,
#    1,
#    42,
#    39,
#    27,
#    20,
#    43,
#    26,
#    24,
#    30],
#   [23, 24, 33, 12, 36, 41, 47, 25, 9, 11]],
#  [35,
#   12,
#   2,
#   20,
#   50,
#   38,
#   7,
#   47,
#   17,
#   11,
#   43,
#   11,
#   22,
#   20,
#   23,
#   9,
#   34,
#   27,
#   40,
#   10,
#   23,
#   41,
#   49,
#   2,
#   14,
#   21,
#   35,
#   50,
#   22,
#   42,
#   11,
#   3,
#   47,
#   17,
#   29,
#   9,
#   10,
#   48,
#   37,
#   22,
#   32,
#   37,
#   17,
#   45,
#   29,
#   46,
#   43,
#   45,
#   37,
#   13])

# %%
def f2(L, T, V=0, S=False):
    import random
    test_num = round((T / 100) * len(L))
    val_num = round((V / 100) * len(L))
    list_test = []
    list_val = []
    list_train = []
    if S == False:
        list_test = L[:test_num]
        L = L[test_num:]
        if len(L) > 1:
            list_val = L[:val_num]
            L = L[val_num:]
            list_train = L
        else:
            list_train = L

    else:
        random.shuffle(L)
        list_test = L[:test_num]
        L = L[test_num :]
        if len(L) > 1:
            list_val = L[:val_num]
            L = L[val_num :]
            list_train = L
        else:
            list_train = L

    
    print('len list_train:',len(list_train))
    print('len list_val:',len(list_val))
    print('len list_test:',len(list_test))
    return list_train,list_val, list_test

# %%
f2(rand_list, T=10, S=True)
# Out:
# len list_train: 90
# len list_val: 0
# len list_test: 10
# ([46,
#   10,
#   12,
#   41,
#   17,
#   23,
#   36,
#   17,
#   3,
#   18,
#   47,
#   9,
#   11,
#   20,
#   22,
#   11,
#   37,
#   11,
#   24,
#   43,
#   37,
#   29,
#   19,
#   7,
#   9,
#   44,
#   35,
#   9,
#   28,
#   20,
#   24,
#   32,
#   45,
#   15,
#   24,
#   13,
#   2,
#   40,
#   26,
#   21,
#   23,
#   10,
#   20,
#   50,
#   27,
#   9,
#   24,
#   11,
#   43,
#   17,
#   22,
#   17,
#   2,
#   41,
#   7,
#   14,
#   46,
#   26,
#   42,
#   35,
#   42,
#   36,
#   2,
#   17,
#   32,
#   3,
#   1,
#   41,
#   29,
#   22,
#   23,
#   45,
#   50,
#   16,
#   25,
#   48,
#   12,
#   43,
#   38,
#   21,
#   34,
#   9,
#   49,
#   47,
#   9,
#   3,
#   47,
#   37,
#   30,
#   36],
#  [],
#  [50, 27, 15, 39, 22, 49, 33, 39, 23, 27])
